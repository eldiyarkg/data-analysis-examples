# %%
import pandas as pd

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[4,16,19,27,28,33])

# %%
df.fillna('', inplace=True)

# %%
df.rename(columns={4:'name',16:'address',19:'phone',27:'director',28:'activity',33:'founders'},inplace=True)

# %%
df
# Out:
#                                                      name  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df['name'][27]
# Out:
# 'Общество с ограниченной ответственностью "Шох"'

# %%
df.loc[3:8, ['director', 'activity']]
# Out:
#                            director                           activity
# 3       Бражников Сергей Алексеевич                                NaN
# 4        Абдылдаев Нурлан Киршеевич                                NaN
# 5  Жумашукуров Жыпарбек Байчукуевич           Рыбоводство пресноводное
# 6                 Калманбетов Баялы                                NaN
# 7          Рунов Вениамин Федорович                                NaN
# 8                    Каримов Руслан  Оптовая торговля  лесоматериалами

# %%
df.loc[389:5678]
# Out:
#                                                    name  \
# 389   Общественное объединение "Бишкекский центр пси...
# 390   Общественный фонд "Благотворительный обществен...
# 391   АО закрытого типа " УРАН " (находится в процес...
# 392                                 ОсОО " КЫЗЫЛ-КАРА "
# 393   Управление внебюджетной деятельности Министерс...
# 394   Ошское представительство Фонд Развития сельско...
# 395        Обшественный Благотворительный фонд " НИЕТ "
# 396                                    ООО "БАЙТИК-ТУР"
# 397   ООО  Научно-производственное  объединение  " С...
# 398                                      ОсОО " ШАБАН "
# 399   Некоммерческая организация жилищно-строительны...
# 400   Объединение работодателей"Ассоциация содействи...
# 401                                      ОсОО " МГМ-А "
# 402                           Общественный фонд "Сахий"
# 403                                  ОсОО " V. Alisher"
# 404                            Учреждение"Бизнес-Центр"
# ...

# %%
df.loc[[1,2,58,76]]
# Out:
#                                                  name  \
# 1                                   ОО "Кайберен эне"
# 2   Общество с ограниченной ответственностью "Дете...
# 58       РО "Церковь Евангельских христиан-баптистов"
# 76     Иностранное Турецкое ООО "Turk Elektro Ternir"
#
#                           director  \
# 1      Омурбеков Алмаз Ороскулович
# 2   Жансеркеев аманат Базарканович
# 58          Лунёв Борис Савельевич
# 76                   Зекерия Балык
#
#                                             activity  \
# 1                                                NaN
# 2   Обеспечение общественного порядка и безопасности
# 58                                               NaN
# 76                                               NaN
#
#                            founders
# 1             инициаторы 10 человек
# 2    Жансеркеев аманат Базарканович
# 58  инициаторы по списку 10-человек
# 76        екерия Балык, Фантих Турк

# %%
df.loc[:15]
# Out:
#                                                  name  \
# 0   Коммерческий кооператив "Семеноводческий произ...
# 1                                   ОО "Кайберен эне"
# 2   Общество с ограниченной ответственностью "Дете...
# 3              Иностранное Казахское ОсОО "Валькирия"
# 4                                      ОсОО "Harour''
# 5   Государственное предприятие "Иссык-кульское ры...
# 6                    ОсОО Редакция газеты " Эл созу "
# 7        РО "Церковь Евангельских христиан-баптистов"
# 8     Общество с ограниченной ответственностью "Вояж"
# 9         РО "Церковь Евангельских Христян-баптистов"
# 10  Общество с ограниченной ответственностью "Мана...
# 11  Совместное кыргызско-казахстанское общество с ...
# 12             Производственный кооператив "Кожешкен"
# 13           Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14       Южное отделение Национального агенства связи
# 15  Общество с ограниченной ответственностью "Жолб...
#
#                             director  \
# ...

# %%
df.loc[111110:]
# Out:
#                                                      name  \
# 111110  Общество с ограниченной ответственностью "Акса...
# 111111  Общество с ограниченной ответственностью "Микр...
# 111112  Общество с ограниченной ответственностью "Хан ...
# 111113  Общество с ограниченной ответственностью "Лого...
# 111114  Сельскохозяйственный производственный кооперат...
# 111115  Филиал Открытого акционерного общества "Россий...
# 111116   Общество с ограниченной ответственностью "Тулга"
# 111117  Общество с ограниченной ответственностью "Эйч ...
# 111118  Общество с ограниченной ответственностью "Техо...
# 111119  Общество с ограниченной ответственностью "Алан...
# 111120     Учреждение "Нарынский районный отдел культуры"
# 111121  Общество с ограниченной ответственностью "Фина...
# 111122  Общество с ограниченной ответственностью "Кырг...
# 111123  Общество с ограниченной ответственностью "Кырг...
# 111124           Общественное объединение "Доолотбек "К""
# ...

# %%
df.loc[389:5678, 'activity']
# Out:
# 389           Деятельность санаторно-курортных учреждений
# 390     Деятельность прочих общественных организаций, ...
# 391                                                   NaN
# 392                                                   NaN
# 393                                                   NaN
# 394     Предоставление услуг по обработке урожая сельс...
# 395     Деятельность прочих общественных организаций, ...
# 396                                                   NaN
# 397                                                   NaN
# 398                                                   NaN
# 399                                                   NaN
# 400     Прочее социальное обслуживание без обеспечения...
# 401                                                   NaN
# 402     Деятельность общественных организаций (объедин...
# 403                                                   NaN
# 404     Консультирование по вопросам связи с обществен...
# ...

# %%
df.loc[[1,2,58,76],['activity']]
# Out:
#                                             activity
# 1                                                NaN
# 2   Обеспечение общественного порядка и безопасности
# 58                                               NaN
# 76                                               NaN

# %%
df.loc[:15,'activity']
# Out:
# 0     Выращивание зерновых культур (кроме риса и гре...
# 1                                                   NaN
# 2      Обеспечение общественного порядка и безопасности
# 3                                                   NaN
# 4                                                   NaN
# 5                              Рыбоводство пресноводное
# 6                                                   NaN
# 7                                                   NaN
# 8                     Оптовая торговля  лесоматериалами
# 9                                                   NaN
# 10    Прочие строительно-монтажные работы, не включе...
# 11    Прочая деятельность по организации отдыха и ра...
# 12           Обработка риса и производство рисовой муки
# 13    Прочие строительно-монтажные работы, не включе...
# 14                                                  NaN
# 15    Оптовая торговля прочими  непродовольственными...
# Name: activity, dtype: object

# %%
df.loc[111110:,'activity']
# Out:
# 111110    Охота, разведение диких животных и  предоставл...
# 111111                               Предоставление кредита
# 111112    Деятельность агентов по оптовой торговле товар...
# 111113    Производство строительных металлических констр...
# 111114    Разведение крупного рогатого скота молочного н...
# 111115                                  Деятельность банков
# 111116                Оптовая неспециализированная торговля
# 111117                     Технические испытания и контроль
# 111118                     Технические испытания и контроль
# 111119    Прочая деятельность в области образования, не ...
# 111120      Образовательная деятельность в области культуры
# 111121    Деятельность в области бухгалтерского учета и ...
# 111122    Строительство прочих объектов гражданского наз...
# 111123    Производство кирпича, черепицы и прочих строит...
# 111124    Деятельность общественных организаций (объедин...
# 111125                 Строительство жилых и нежилых зданий
# ...

# %%
df.loc[389:5678,['name','founders']]
# Out:
#                                                    name  \
# 389   Общественное объединение "Бишкекский центр пси...
# 390   Общественный фонд "Благотворительный обществен...
# 391   АО закрытого типа " УРАН " (находится в процес...
# 392                                 ОсОО " КЫЗЫЛ-КАРА "
# 393   Управление внебюджетной деятельности Министерс...
# 394   Ошское представительство Фонд Развития сельско...
# 395        Обшественный Благотворительный фонд " НИЕТ "
# 396                                    ООО "БАЙТИК-ТУР"
# 397   ООО  Научно-производственное  объединение  " С...
# 398                                      ОсОО " ШАБАН "
# 399   Некоммерческая организация жилищно-строительны...
# 400   Объединение работодателей"Ассоциация содействи...
# 401                                      ОсОО " МГМ-А "
# 402                           Общественный фонд "Сахий"
# 403                                  ОсОО " V. Alisher"
# 404                            Учреждение"Бизнес-Центр"
# ...

# %%
df.loc[[1,2,58,76],['name','founders']]
# Out:
#                                                  name  \
# 1                                   ОО "Кайберен эне"
# 2   Общество с ограниченной ответственностью "Дете...
# 58       РО "Церковь Евангельских христиан-баптистов"
# 76     Иностранное Турецкое ООО "Turk Elektro Ternir"
#
#                            founders
# 1             инициаторы 10 человек
# 2    Жансеркеев аманат Базарканович
# 58  инициаторы по списку 10-человек
# 76        екерия Балык, Фантих Турк

# %%
df.loc[[:15],['name','founders']]
# Out:
#   File "<ipython-input-39-9a7344b22b1c>", line 1
#     df.loc[[:15],['name','founders']]
#             ^
# SyntaxError: invalid syntax

# %%
df.loc[:15,['name','founders']]
# Out:
#                                                  name  \
# 0   Коммерческий кооператив "Семеноводческий произ...
# 1                                   ОО "Кайберен эне"
# 2   Общество с ограниченной ответственностью "Дете...
# 3              Иностранное Казахское ОсОО "Валькирия"
# 4                                      ОсОО "Harour''
# 5   Государственное предприятие "Иссык-кульское ры...
# 6                    ОсОО Редакция газеты " Эл созу "
# 7        РО "Церковь Евангельских христиан-баптистов"
# 8     Общество с ограниченной ответственностью "Вояж"
# 9         РО "Церковь Евангельских Христян-баптистов"
# 10  Общество с ограниченной ответственностью "Мана...
# 11  Совместное кыргызско-казахстанское общество с ...
# 12             Производственный кооператив "Кожешкен"
# 13           Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14       Южное отделение Национального агенства связи
# 15  Общество с ограниченной ответственностью "Жолб...
#
# ...

# %%
df.loc[111110:,['name','founders']]
# Out:
#                                                      name  \
# 111110  Общество с ограниченной ответственностью "Акса...
# 111111  Общество с ограниченной ответственностью "Микр...
# 111112  Общество с ограниченной ответственностью "Хан ...
# 111113  Общество с ограниченной ответственностью "Лого...
# 111114  Сельскохозяйственный производственный кооперат...
# 111115  Филиал Открытого акционерного общества "Россий...
# 111116   Общество с ограниченной ответственностью "Тулга"
# 111117  Общество с ограниченной ответственностью "Эйч ...
# 111118  Общество с ограниченной ответственностью "Техо...
# 111119  Общество с ограниченной ответственностью "Алан...
# 111120     Учреждение "Нарынский районный отдел культуры"
# 111121  Общество с ограниченной ответственностью "Фина...
# 111122  Общество с ограниченной ответственностью "Кырг...
# 111123  Общество с ограниченной ответственностью "Кырг...
# 111124           Общественное объединение "Доолотбек "К""
# ...

# %%
df.loc[df['director']=='Каримов Руслан']
# Out:
#                                                   name        director  \
# 8      Общество с ограниченной ответственностью "Вояж"  Каримов Руслан
# 67579  Общество с ограниченной ответственностью "Вояж"  Каримов Руслан
#
#                                 activity        founders
# 8      Оптовая торговля  лесоматериалами  Каримов Руслан
# 67579  Оптовая торговля  лесоматериалами  Каримов Руслан

# %%
df.loc[df['director']==df['founders']]
# Out:
#                                                      name  \
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 8         Общество с ограниченной ответственностью "Вояж"
# 10      Общество с ограниченной ответственностью "Мана...
# 15      Общество с ограниченной ответственностью "Жолб...
# 24      Общество с ограниченной ответственностью "КМ-С...
# 27         Общество с ограниченной ответственностью "Шох"
# 29      Общество с ограниченной ответственностью "Чынгыз"
# 30                                         ООО "АЛМАЗ RT"
# 31      Общество с ограниченной ответственностью "Адил...
# 35       Общество с ограниченной ответственностью "Кунан"
# 37        Учреждение "Центр национальных игр Мира-"МАНАС"
# 40      Акционерное общество закрытого типа "Юнион-Кон...
# 44                                     ОсОО "Лаачын-Ордо"
# 46                       ОсОО Редакция газеты "АНТИМАГИЯ"
# ...

# %%
df.loc[df['director']==df['founders'],'director']
# Out:
# 2            Жансеркеев аманат Базарканович
# 3               Бражников Сергей Алексеевич
# 8                            Каримов Руслан
# 10                           Шафиев Юлчувай
# 15                           Юсупов Арабжан
# 24                       Тумонбаева Гульзат
# 27             Таджибаев Шавхат Эргешбаевич
# 29                         Токторбаев Сатты
# 30              Волочай Светлана Васильевна
# 31               Асанов Сапарбай Анарбаевич
# 35                Когай Бронислав Андреевич
# 37                        Керексизов Ташкул
# 40               Мамбетов Кубатбек Толуевич
# 44               Омуралиева Айжан Касымовна
# 46                        Чолпонова Анаркан
# 47              Ибраимов Темир Намазбекович
# 49                  Пыхтеев Игорь Борисович
# 56                       Кочкорбаев Абдилат
# 63                        Эгембердиев Шарап
# 64        Абдраимова Майрамбубу Джекшеновна
# 65              Жураев Лукмонжон Рузалиевич
# ...

# %%
def a_x_2(a):
    return a * 2

# %%
a_x_2(2.98)
# Out:
# 5.96

# %%
a = lambda x: a_x_2(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-adf3103c7c3e> in <module>
# ----> 1 len()
#
# TypeError: len() takes exactly one argument (0 given)

# %%
def count_letters(word):
    return len(word)

# %%
count_letters('eldiyar')
# Out:
# 7

# %%
df
# Out:
#                                                      name  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df[df['address'].str.contains("Гоголя")]
# Out:
#                                                      name       address  \
# 201     Учреждение-Классы с оказанием платных образова...        Гоголя
# 591               Иностранное ООО "HEPPY HEAR TRADING CO"        Гоголя
# 900     Иностранное американского ОсОО "Центр по изуче...        Гоголя
# 906                                          ОсОО "Термы"        Гоголя
# 956     ОО " Ассоциация  SURF & SNOW BOARDING  ( Парус...        Гоголя
# 1058                                      ОсОО "З.Е.В.С."        Гоголя
# 1175                                   ОсОО фирма "Хамид"        Гоголя
# 1184                          Центр открытого образования        Гоголя
# 1520    Кыргызско-саудовско-аравийское ОсОО "Ум аль Кура"        Гоголя
# 1754                   Редакция газеты "Ислам маданияты "        Гоголя
# 1810        ООО Торгово-промышленная  компания "ТАМЕРЛАН"        Гоголя
# 2099                                      ОсОО " Висла  "        Гоголя
# ...

# %%
df[df['founders'].str.contains("Эльдияр")]
# Out:
#                                                      name  \
# 2330     Общество с ограниченной ответственностью "Элбол"
# 8983    Общество с ограниченной ответственостью "Серви...
# 10304     Общество с ограниченной ответсвенностью "Недры"
# 12088   Общество с ограниченной ответстсвенностью "Юге...
# 13395   Общество с ограниченной ответсвенностью "SOUTH...
# 13415                                     "Золотая карта"
# 16435   ОсОО "Охранно-детективное агентство "Илбирс Се...
# 21993                              ОсОО "Авангард Сервис"
# 22105                    ОФ Молодежнный институт развития
# 29322                           ОФ имени Дононбаева Алима
# 31691                               ОсОО "Алаткен-Тревел"
# 31960                               ОсОО "Стройтехмонтаж"
# 33864                                ОсОО "ТРОФЕЙ-КЫРЧЫН"
# 55536   Общество с ограниченной ответственностью "Торг...
# 55607   Общество с органиченной ответственностью "CZEC...
# ...

# %%
df[df['founders'].str.contains("Эльдияр")&df['address'].str.contains("Гоголя")]
# Out:
# Empty DataFrame
# Columns: [name, address, director, activity, founders]
# Index: []

# %%
df[df['founders'].str.contains('Тухватшин Рустам')]
# Out:
#                               name    address          director activity  \
# 45599     ОсОО "РТР-МЕДИКАЛ ПРОФИ"  Ахунбаева  Тухватшин Рустам
# 48820  Общественный фонд "ЭЛ-КУРУ"  Матросова    Черникова Н.Г.
#
#                                                 founders
# 45599                                   Тухватшин Рустам
# 48820  Тухватшин Рустам Романович, Сыдыков Кубанычбек...

# %%
df[df['founders'].str.contains('Искендер Бектур')]
# Out:
#                                                name    address  \
# 21872  Общественный фонд "Kloop Media"(Клоп Медиа)   Ахунбаева
#
#                        director  \
# 21872  Гапарова Галина Ивановна
#
#                                                 activity  \
# 21872  Деятельность прочих общественных организаций, ...
#
#                                           founders
# 21872  Тухватшин Ринат Рустамович, Искендер Бектур

# %%
df[df['activity'].str.contains('строит')&df['phone'].str.contains("432")]
# Out:
#                                                      name         address  \
# 4452    Общество с ограниченной ответственностью «МосС...   ул. Заводская
# 68017   Филиал Общества с ограниченной ответственность...  ул. Логвиненко
# 77115   Общество с ограниченной ответственностью "Адил...
# 85882   Общество с ограниченной ответственностью "Ала-...
# 88964   Общество с ограниченной ответственностью "Хонг...   пр. Масалиева
# 91465   Общество с ограниченной ответственностью "Чина...
# 93797   Общество с ограниченной ответственностью "Аясман"
# 104906  Общество с ограниченной ответственностью "МАКЕ...     ул.Ананьева
#
#              phone                          director  \
# 4452    0555243277            Шек Андрей Анатольевич
# 68017   0554324324      Синицын Виктор Александрович
# 77115   0776432044          Эргешов Нурлан Камчиевич
# 85882   0555604325      Туйчиев Султанбек Сатангович
# 88964   0555604325                         Ванг Юкин
# ...

# %%
df.loc[df['activity'].str.contains('строит')&df['phone'].str.contains("432"),['name','address','director']]
# Out:
#                                                      name         address  \
# 4452    Общество с ограниченной ответственностью «МосС...   ул. Заводская
# 68017   Филиал Общества с ограниченной ответственность...  ул. Логвиненко
# 77115   Общество с ограниченной ответственностью "Адил...
# 85882   Общество с ограниченной ответственностью "Ала-...
# 88964   Общество с ограниченной ответственностью "Хонг...   пр. Масалиева
# 91465   Общество с ограниченной ответственностью "Чина...
# 93797   Общество с ограниченной ответственностью "Аясман"
# 104906  Общество с ограниченной ответственностью "МАКЕ...     ул.Ананьева
#
#                                 director
# 4452              Шек Андрей Анатольевич
# 68017       Синицын Виктор Александрович
# 77115           Эргешов Нурлан Камчиевич
# 85882       Туйчиев Султанбек Сатангович
# 88964                          Ванг Юкин
# 91465   Закиров Абдил-Насир Сооронбаевич
# 93797          Григорьев Борис Георгевич
# ...

# %%
df.loc[df['address'].str.contains("Гоголя"),['name','address','director']]
# Out:
#                                                      name       address  \
# 201     Учреждение-Классы с оказанием платных образова...        Гоголя
# 591               Иностранное ООО "HEPPY HEAR TRADING CO"        Гоголя
# 900     Иностранное американского ОсОО "Центр по изуче...        Гоголя
# 906                                          ОсОО "Термы"        Гоголя
# 956     ОО " Ассоциация  SURF & SNOW BOARDING  ( Парус...        Гоголя
# 1058                                      ОсОО "З.Е.В.С."        Гоголя
# 1175                                   ОсОО фирма "Хамид"        Гоголя
# 1184                          Центр открытого образования        Гоголя
# 1520    Кыргызско-саудовско-аравийское ОсОО "Ум аль Кура"        Гоголя
# 1754                   Редакция газеты "Ислам маданияты "        Гоголя
# 1810        ООО Торгово-промышленная  компания "ТАМЕРЛАН"        Гоголя
# 2099                                      ОсОО " Висла  "        Гоголя
# ...

# %%
df.loc[df['founders'].str.contains("Эльдияр"),['name','address','director']]
# Out:
#                                                      name  \
# 2330     Общество с ограниченной ответственностью "Элбол"
# 8983    Общество с ограниченной ответственостью "Серви...
# 10304     Общество с ограниченной ответсвенностью "Недры"
# 12088   Общество с ограниченной ответстсвенностью "Юге...
# 13395   Общество с ограниченной ответсвенностью "SOUTH...
# 13415                                     "Золотая карта"
# 16435   ОсОО "Охранно-детективное агентство "Илбирс Се...
# 21993                              ОсОО "Авангард Сервис"
# 22105                    ОФ Молодежнный институт развития
# 29322                           ОФ имени Дононбаева Алима
# 31691                               ОсОО "Алаткен-Тревел"
# 31960                               ОсОО "Стройтехмонтаж"
# 33864                                ОсОО "ТРОФЕЙ-КЫРЧЫН"
# 55536   Общество с ограниченной ответственностью "Торг...
# 55607   Общество с органиченной ответственностью "CZEC...
# ...

# %%
df.loc[df['founders'].str.contains("Эльдияр")&df['address'].str.contains("Гоголя"),['name','address','director']]
# Out:
# Empty DataFrame
# Columns: [name, address, director]
# Index: []

# %%
df.loc[df['founders'].str.contains('Искендер Бектур'),['name','address','director']]
# Out:
#                                                name    address  \
# 21872  Общественный фонд "Kloop Media"(Клоп Медиа)   Ахунбаева
#
#                        director
# 21872  Гапарова Галина Ивановна

# %%
df.loc[df['founders'].str.contains('Ботбаев Асан'),['name','address','director']]
# Out:
#                                                     name          address  \
# 99239  Общество с ограниченной ответственностью "Fant...  ул. Кийизбаевой
#
#                      director
# 99239  Ботбаев Асан Болотович
